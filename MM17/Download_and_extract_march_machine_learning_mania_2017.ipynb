# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Download a file based on its file ID.
#
# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
file_id = '1QLoZOyVJuD7SsfYo7jV7cyLhooeitXaJ'
file_name = 'march-machine-learning-mania-2017.zip'
downloaded = drive.CreateFile({'id': file_id})
#print('Downloaded content "{}"'.format(downloaded.GetContentString()))
downloaded.GetContentFile(file_name)

# %%
from zipfile import ZipFile

# %%
with ZipFile(file_name, 'r') as zip:
  zip.extractall()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-05e72acd36e0> in <module>
# ----> 1 with ZipFile(file_name, 'r') as zip:
#       2   zip.extractall()
#
# NameError: name 'file_name' is not defined

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# Out:
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?

# %%
# !wget -q http://apache.osuosl.org/spark/spark-2.3.2/spark-2.3.2-bin-hadoop2.7.tgz

# %%
# !tar xf spark-2.4.0-bin-hadoop2.7.tgz
# !pip install -q findspark
# Out:
# tar: spark-2.4.0-bin-hadoop2.7.tgz: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.0-bin-hadoop2.7"

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-3e51e97f758b> in <module>
#       1 import findspark
# ----> 2 findspark.init()
#       3 from pyspark.sql import SparkSession
#       4 spark = SparkSession.builder.master("local[*]").getOrCreate()
#
# /opt/conda/lib/python3.7/site-packages/findspark.py in init(spark_home, python_path, edit_rc, edit_profile)
#     133     # add pyspark to sys.path
#     134     spark_python = os.path.join(spark_home, 'python')
# --> 135     py4j = glob(os.path.join(spark_python, 'lib', 'py4j-*.zip'))[0]
#     136     sys.path[:0] = [spark_python, py4j]
#     137
#
# IndexError: list index out of range

# %%
import pandas as pd

# %%
def read_csv(csv_name):
  return(pd.read_csv(csv_name+'.csv'))

# %%
regular_season_compact_results = read_csv('RegularSeasonCompactResults')
regular_season_detailed_results = read_csv('RegularSeasonDetailedResults')
sample_submission = read_csv('SampleSubmission')
seasons = read_csv('Seasons')
teams = read_csv('Teams')
tourney_compact_results = read_csv('TourneyCompactResults')
tourney_detailed_results = read_csv('TourneyDetailedResults')
tourney_seeds = read_csv('TourneySeeds')
tourney_slots = read_csv('TourneySlots')

# %%
regular_season_detailed_results
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  Wfgm  Wfga  \
# 0        2003      10   1104      68   1328      62    N      0    27    58
# 1        2003      10   1272      70   1393      63    N      0    26    62
# 2        2003      11   1266      73   1437      61    N      0    24    58
# 3        2003      11   1296      56   1457      50    N      0    18    38
# 4        2003      11   1400      77   1208      71    N      0    30    61
# 5        2003      11   1458      81   1186      55    H      0    26    57
# 6        2003      12   1161      80   1236      62    H      0    23    55
# 7        2003      12   1186      75   1457      61    N      0    28    62
# 8        2003      12   1194      71   1156      66    N      0    28    58
# 9        2003      12   1458      84   1296      56    H      0    32    67
# 10       2003      13   1166     106   1426      50    H      0    41    69
# ...

# %% [raw]
# regular_season_detailed_results

# %%
regular_season_detailed_results.registerTempTable('regular_season_detailed_results')

# %%
teams.registerTempTable('teams')

# %%
sql = """
create or replace temporary view regular_season_detailed_results_team_names as 
select regular_season_detailed_results.*,
       winning_team.Team_Name as winning_team_name,
       losing_team.Team_Name as losing_team_name
from regular_season_detailed_results
left join teams winning_team on winning_team.Team_ID = regular_season_detailed_results.Wteam
left join teams losing_team on losing_team.Team_ID = regular_season_detailed_results.Lteam
"""

# %%
Wteam
# Out:
# DataFrame[]

# %%
spark.sql('select * from regular_season_detailed_results_team_names').toPandas()
# Out:
#        Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot  Wfgm  Wfga  \
# 0        2003      10   1104      68   1328      62    N      0    27    58
# 1        2003      10   1272      70   1393      63    N      0    26    62
# 2        2003      11   1266      73   1437      61    N      0    24    58
# 3        2003      11   1296      56   1457      50    N      0    18    38
# 4        2003      11   1400      77   1208      71    N      0    30    61
# 5        2003      11   1458      81   1186      55    H      0    26    57
# 6        2003      12   1161      80   1236      62    H      0    23    55
# 7        2003      12   1186      75   1457      61    N      0    28    62
# 8        2003      12   1194      71   1156      66    N      0    28    58
# 9        2003      12   1458      84   1296      56    H      0    32    67
# 10       2003      13   1166     106   1426      50    H      0    41    69
# ...

# %%
spark.sql('select * from regular_season_detailed_results_team_names').write.csv('regular_season_detailed_results_team_names.csv')

# %%
spark.sql('select * from regular_season_detailed_results_team_names').toPandas().to_csv('regular_season_detailed_results_team_names_unpartitioned.csv')

# %% [markdown]
# NBA API
